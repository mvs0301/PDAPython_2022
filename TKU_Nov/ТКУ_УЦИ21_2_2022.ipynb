# %% [markdown]
# <img src="../Img/banner-fa-49-2.png">
#
# 5 ноября 2022 года, ВМ_стр1/201-1, ул. Верхняя Масловка, д. 15<br>
# 14:00 - 15:30, 4-я пара<br>
#
# Студенты: УЦИ21-2<br>
#
# Преподаватель: Смирнов Михаил Викторович,<br>
# доцент Департамента анализа данных и машинного обучения<br>
# Финансового университета при Правительстве Российской Федерации
#
# <h2 style="color:#7F0037"> Контрольная работа</h2>
#
# Переименуйте этот файл <Фамилия Имя группа>. Выполните задания в этом файле и отправьте преподавателю на почту со своего универститетского почтового ящика.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 1</p>
#
# В строке "Финансовый университет" удалите пробелы, а затем создайте словарь, в котором ключами являются чётные номера символов получившейся после удаления пробелов строки. Считайте, что первый символ строки имеет номер 0, второй символ номер 1 и так далее. На печать необходимо вывести только чётные номера. Ожидается результат
# ```
# {0: 'Ф', 2: 'н', 4: 'н', 6: 'о', 8: 'ы', 10: 'у', 12: 'и', 14: 'е', 16: 'с', 18: 'т', 20: 'т'}
# ```

# %%
# Задание 1. Ваш код здесь.

s="Финансовый университет"

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 2</p>
#
# Для списка вида
# ```
# lst1=[['Дрезден', 3, 5, 4], ['Воркута', 4, 5, 5], ['Якутск', 3, 3, 3], ['Николаев', 4, 4, 3]]
# ```
# напишите программу, которая выводит на экран этот список в виде таблицы отсортированной по последнему параметру. Для этого используйте шаблон
#
# ```
# for item in sorted(lst1, key=lambda x: <?>):
#     print(f'{item[0]}  \t {item[1]} \t {item[2]} \t <?>')
# ```
#
# Подставьте Ваш код в места, отмеченные $\text{<?>}$. Ожидается результат:
#
# ```
# Якутск       3   3   3
# Николаев     4   4   3
# Дрезден      3   5   4
# Воркута      4   5   5
# ```
#
# Вы можете составить свой оригинальный вариант решения этой задачи и не пользоваться предоставленным шаблоном.

# %%
# Задание 2. Ваш код здесь.

lst1=[['Дрезден', 3, 5, 4], ['Воркута', 4, 5, 5], ['Якутск', 3, 3, 3], ['Николаев', 4, 4, 3]]

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 3</p>
#
# Пользователь вводит три числа через пробел. Присвойте их объектам $a, b$ и $n$. Посчитайте и выведите на экран сумму всех чисел, кратных $n$, расположенных в диапазоне от $a-1$ до $b+1$.

# %%
# Задание 3. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 4 </p>
#
# Создайте функцию, которая рисует перевернутый равнобедренный треугольник с основанием $k$ символов $p$. В качестве основания треугольника используйте какое-либо нечетное натуральное число, например 3, 5, 7, 9. Функция должна иметь два параметра: число $k$ и символ $p$, используемый для рисования.
#
# Например, для $k=7$ и $p=\text{'*'}$ ожидается результат:
#
# ```
# *******
#  *****
#   ***
#    *
# ```

# %%
# Задание 4. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 5
#
# Найдите точку $M=(x_{0},y_{0})$ максимума функции $f(x)$ в интервале $[a;b]$ с шагом $h$. Используйте следующие значения:
#
# $$f(x)=x \cdot sin(x-1), a=-\pi, b=\pi, h=0.1$$
#
# Результат округлите до двух десятичных знаков. Ожидается ответ:
#
# ```
# Точка максимума функции M=(<x>,<y>)
# ```

# %%
# Задание 5. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 6
#
# Даны целые положительные числа $M$ и $N$. Сформировать целочисленный список списков размера $M \times N$, у которого все элементы $J$-го столбца имеют значение $3 \cdot J, J = 1, . . ., N$.
#
# Для $M=5$ и $k=7$ ожидается результат
#
# ```
# [[3, 6, 9, 12, 15, 18, 21],
#  [3, 6, 9, 12, 15, 18, 21],
#  [3, 6, 9, 12, 15, 18, 21],
#  [3, 6, 9, 12, 15, 18, 21],
#  [3, 6, 9, 12, 15, 18, 21]]
# ```

# %%
# Задание 6. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 7
#
# Имеется словарь с наименованиями продуктов и ценами.
#
# ```
# {'apples': 20, 'grape': 25, 'bananas': 15, 'tomatoes': 15, 'melons': 11}
# ```
#
# Все цены снижены на 60%. Внесите изменения в словарь и распечатайте.

# %%
# Задание 7. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 8
#
# Для приготовления блюд национальной кухни используются следующие продукты (ingredients):
#
# ```
# ingredients={
#     "indian":["vegetable oil","wheat","black pepper",
#               "cayenne pepper","onions","milk","butter","sugar",
#               "salt","lemon","natural yogurt","carrots","rice"],
#     "chinese":["sesame oil","black pepper",
#                "cayenne pepper","canola oil","sugar",
#                "garlic","red pepper","yellow peppers","broccoli",
#                "green bell pepper","vegetable oil","eggs","onions","rice"],
#     "korean":["daikon","red radishes","onions","salt","carrots",
#               "garlic","black pepper","eggs"]
# }
# ```
#
# a) Сколько всего различных продуктов входит в состав разных кухонь?<br>
# б) Перечислите продукты, которые входят в состав только одной кухни, сколько таких продуктов?<br>
# в) Найдите все виды перца (pepper) используемые во всех кухнях.<br>

# %%
# Задание 8. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 9
#
# Даны целые числа $N>2$, $A$ и $B$. Сформировать и вывести список размера $N$, первый элемент которого равен $A$, второй равен $B$, а каждый последующий элемент равен сумме всех предыдущих.

# %%
# Задание 9. Ваш код здесь.

# %% [markdown]
# <p style="font-size:130%; color:#7F0037"> Задание 10
#
# Имеются два списка целых чисел, упорядоченные по возрастанию. Получите новый список, содержащий все элементы исходных списков, в котором элементы также упорядочены в порядке возрастания, не используя встроенных методов сортировки.
#
# Пример:
# ```
# a=[2,17,18,23,30]
# b=[4,14,19,21,29]
#
# [2,4,14,17,18,19,21,23,29,30]
# ```

# %%
# Задание 10. Ваш код здесь.

a=[2,17,18,23,30]
b=[4,14,19,21,29]
