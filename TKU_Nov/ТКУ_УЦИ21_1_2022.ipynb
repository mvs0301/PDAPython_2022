# %% [markdown]
# <img src="../Img/banner-fa-49-2.png">
#
# 1 ноября 2022 года, ВМ_стр1/201-1, ул. Верхняя Масловка, д. 15<br>
# 15:40 - 17:10, 5-я пара<br>
#
# Студенты: УЦИ21-1<br>
#
# Преподаватель: Смирнов Михаил Викторович,<br>
# доцент Департамента анализа данных и машинного обучения<br>
# Финансового университета при Правительстве Российской Федерации
#
#
# # Контрольная работа

# %% [markdown]
# ### Задание 1
#
# В строке "На берегу моря стоял дом" удалите пробелы, а затем создайте словарь, в котором ключами будут нечётные номера символов получившейся после удаления пробелов строки, начиная от единицы, а значениями - сами символы. Ожидается результат
# ```
# {1: 'Н', 3: 'б', 5: 'р', 7: 'г', 9: 'м', 11: 'р', 13: 'с', 15: 'о', 17: 'л', 19: 'о'}
# ```

# %%
# Задание 1. Ваш код здесь.

# %% [markdown]
# ### Задание 2
#
# Для списков вида
# ```
# [['Иванов', 3, 5, 4], ['Петров', 4, 5, 5], ['Сидоров', 3, 3, 3], ['Николаев', 4, 4, 3]]
# ```
# напишите программу, которая выводит на экран этот список в виде таблицы в отсортированном по фамилии виде. Ожидается результат.
#
# ```
# Иванов  	 3 	 5 	 4
# Николаев     4 	 4 	 3
# Петров  	 4 	 5 	 5
# Сидоров      3 	 3 	 3
# ```

# %%
# Задание 2. Ваш код здесь.

# %% [markdown]
# ### Задание 3
#
# Пользователь вводит три числа через пробел. Присвойте их объектам $a, b$ и $n$. Посчитайте и выведите на экран сумму всех чисел, кратных $n$, расположенных в диапазоне от $a-1$ до $b+1$.

# %%
# Задание 3. Ваш код здесь.

# %% [markdown]
# ### Задание 4
#
# Создайте функцию, которая рисует символами $p$ равнобедренный треугольник с основанием из $k$ символов. В качестве основания треугольника используйте какое-либо нечетное натуральное число, например 3, 5, 7, 9. Функция должна иметь два параметра: число $k$ и символ $p$, используемый для рисования.
#
# Например, для $k=7$ и $p=\text{'^'}$ ожидается результат:
#
# ```
#    ^
#   ^^^
#  ^^^^^
# ^^^^^^^
# ```

# %%
# Задание 4. Ваш код здесь.

# %% [markdown]
# ### Задание 5
#
# Найдите точку $M=(x_{0},y_{0})$ максимума функции $f(x)$ в интервале $[a;b]$ с шагом $h$. Используйте следующие значения:
#
# $$f(x)=x \cdot sin(x-1), a=-\pi, b=\pi, h=0.1$$
#
# Результат округлите до двух десятичных знаков. Ожидается ответ:
#
# ```
# Точка максимума функции M=(<x>,<y>)
# ```

# %%
# Задание 5. Ваш код здесь.

# %% [markdown]
# ### Задание 6
#
# Даны целые положительные числа $M$ и $N$. Сформировать целочисленный список списков размера $M \times N$, у которого все элементы $J$-го столбца имеют значение $5 \cdot J, J = 1, . . ., N$.
#
# Для $M=5$ и $k=7$ ожидается результат
#
# ```
# [[5, 10, 15, 20, 25, 30, 35],
#  [5, 10, 15, 20, 25, 30, 35],
#  [5, 10, 15, 20, 25, 30, 35],
#  [5, 10, 15, 20, 25, 30, 35],
#  [5, 10, 15, 20, 25, 30, 35]]
# ```

# %%
# Задание 6. Ваш код здесь.

# %% [markdown]
# ### Задание 7
#
# Имеется словарь с наименованиями продуктов и ценами.
#
# ```
# {'apples': 20, 'grape': 25, 'bananas': 15, 'tomatoes': 15, 'melons': 11}
# ```
#
# Все цены снижены на 25%. Внесите изменения в словарь и распечатайте результат.

# %%
# Задание 7. Ваш код здесь.

# %% [markdown]
# ### Задание 8
#
# Для приготовления блюд национальной кухни используются следующие продукты (ingredients):
#
# ```
# ingredients={
#     "indian":["vegetable oil","wheat","black pepper",
#               "cayenne pepper","onions","milk","butter","sugar",
#               "salt","lemon","natural yogurt","carrots","rice"],
#     "chinese":["sesame oil","black pepper",
#                "cayenne pepper","canola oil","sugar",
#                "garlic","red pepper","yellow peppers","broccoli",
#                "green bell pepper","vegetable oil","eggs","onions","rice"],
#     "korean":["daikon","red radishes","onions","salt","carrots",
#               "garlic","black pepper","eggs"]
# }
# ```
#
# a) Сколько всего различных продуктов входит в состав разных кухонь?<br>
# б) Перечислите продукты, которые входят в состав только одной кухни, сколько таких продуктов?<br>
# в) Найдите все виды перца (pepper) используемые во всех кухнях.<br>

# %%
# Задание 8. Ваш код здесь.

# %% [markdown]
# ### Задание 9
#
# Даны целые числа $N>2$, $A$ и $B$. Сформировать и вывести список размера $N$, первый элемент которого равен $A$, второй равен $B$, а каждый последующий элемент равен сумме всех предыдущих.

# %%
# Задание 9. Ваш код здесь.

# %% [markdown]
# ### Задание 10
#
# Имеются два списка целых чисел, упорядоченные по возрастанию. Получите новый список, содержащий все элементы исходных списков, в котором элементы также упорядочены в порядке возрастания, не используя встроенных методов сортировки.
#
# Пример:
# ```
# a=[2,17,18,23,30]
# b=[4,14,19,21,29]
#
# [2,4,14,17,18,19,21,23,29,30]
# ```

# %%
# Задание 10. Ваш код здесь.
