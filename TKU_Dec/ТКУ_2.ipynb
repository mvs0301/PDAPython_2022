# %% [markdown]
# <img src="../Img/banner-fa-49-2.png">
#
# 17 декабря 2022 года, ВМ_стр1/207-1, ул. Верхняя Масловка, д. 15<br>
# 11:50 - 13:20, 3-я пара<br>
#
# Студенты: УЦИ21-2<br>
#
# Преподаватель: Смирнов Михаил Викторович,<br>
# доцент Департамента анализа данных и машинного обучения<br>
# Финансового университета при Правительстве Российской Федерации
#
# <h2 style="color:#7F0037"> Самостоятельная работа</h2>
#
# Переименуйте этот файл <Фамилия Имя группа>. Выполните задания в этом файле и отправьте преподавателю на почту со своего универститетского почтового ящика.

# %% [markdown]
# <h3>Задание 1</h3>
#
# В классическом алгоритме Юлия Цезаря каждый символ исходного секретного сообщения заменяется символом из того же алфавита, отстоящим на три позиции далее. Например, для русского алфавита буква А будет заменена на букву Г, Б – на Д и т. д. Данный алгоритм относится к алгоритмам замены. Символ «.» в конце строки означает признак завершения шифрования.
#
# Пример. Исходный текст: Zb Ra Cx Dyk.
#
# Результат шифровки: Сe Ud Fa Gbn.
#
# Реализовать алгоритм Юлия Цезаря на языке Python для букв русского и английского алфавита.

# %%
# Задание 1. Ваш код здесь.

# %% [markdown]
# <h3>Задание 2</h3>
# Зашифруйте свое имя следующим способом: если буква вашего имени – это гласная буква, тогда в зашифрованной строке повторите данную букву три раза подряд; если буква вашего имени – согласная, то в зашифрованной строке оставьте данную букву неизменной.
#
# Например, Максим $\to$ Маааксииим

# %%
# Задание 2. Ваш код здесь.

# %% [markdown]
# <h3>Задание 3</h3>
#
# На основе строки «Волшебной красоты закат озарил Красноярск» создайте словарь, в котором ключами являются слова, а значениями длины слов в символах.

# %%
# Задание 3. Ваш ответ здесь.

# %% [markdown]
# <h3> Задание 4 </h3>
#
# Имеется список названий месяцев:
#
# `['января', 'февраля', 'марта', 'апреля', 'мая', 'июня', 'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря']`.
#
# Создайте по этому списку словарь, в котором название месяца будет ключом, а номер месяца (от 1 до 12) – значением.

# %%
# Задание 4. Ваш ответ здесь.

# %% [markdown]
# <h3>Задание 5</h3>
# Сформируйте список
#
# ```k = [1, 2, 3, 4, 6, 5, 8, 9, 10]```
#
# Если элементы списка образуют возрастающую последовательность, выведите сообщение "ДА", в противном случае – сообщение "НЕТ".

# %%
# Задание 5. Ваш ответ здесь.

# %% [markdown]
# <h3> Задание 6</h3>
# Создайте двумерный список случайных целых чисел размерностью 7x7. Выведите индексы минимального элемента списка и их значения в виде
#
# ``` ((x,y), value) ```.

# %%
# Задание 6. Ваш ответ здесь.
